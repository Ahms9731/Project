# %%
# !pip install ultralytics
# !pip install supervision # for trackers
# Out:
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 ultralytics-8.3.70 ultralytics-thop-2.0.14
# Requirement already satisfied: supervision in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.3.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (3.10.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.26.4)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.11/dist-packages (from supervision) (4.10.0.84)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.11/dist-packages (from supervision) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.11/dist-packages (from supervision) (6.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.13.1)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.11/dist-packages (from supervision) (4.67.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.17.0)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.70)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: supervision in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.3.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (3.10.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.26.4)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.11/dist-packages (from supervision) (4.10.0.84)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.11/dist-packages (from supervision) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.11/dist-packages (from supervision) (6.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.13.1)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.11/dist-packages (from supervision) (4.67.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.17.0)

# %% [markdown]
# # ByteTrack Tracker

# %% [markdown]
# ## Import necessary libraries

# %%
from ultralytics import YOLO
import cv2
import numpy as np
import supervision as sv
import os
import numpy as np
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## Define some functions to deal with videos

# %%
def read_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)
    return frames

def save_video(ouput_video_frames,output_video_path):
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_video_path, fourcc, 24, (ouput_video_frames[0].shape[1], ouput_video_frames[0].shape[0]))
    for frame in ouput_video_frames:
        out.write(frame)
    out.release()

# %% [markdown]
# ## Define some functions to draw the annotations

# %%
def get_center_of_bbox(bbox):
    x1,y1,x2,y2 = bbox
    return int((x1+x2)/2),int((y1+y2)/2)

def get_bbox_width(bbox):
    return bbox[2]-bbox[0]

def measure_distance(p1,p2):
    return ((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)**0.5

def measure_xy_distance(p1,p2):
    return p1[0]-p2[0],p1[1]-p2[1]

def get_foot_position(bbox):
    x1,y1,x2,y2 = bbox
    return int((x1+x2)/2),int(y2)

# %% [markdown]
# ## Tracker

# %%
class ByteTrack_Tracker:
    def __init__(self, model_path):
        self.model = YOLO(model_path)
        self.tracker = sv.ByteTrack()

    def detect_frames(self, frames):
        batch_size=20
        detections = []
        for i in range(0,len(frames),batch_size):
            detections_batch = self.model.predict(frames[i:i+batch_size],conf=0.1)
            detections += detections_batch
        return detections

    def get_object_tracks(self, frames):

        detections = self.detect_frames(frames)

        tracks={
            "players":[],
            "referees":[],
            "ball":[]
        }

        for frame_num, detection in enumerate(detections):
            cls_names = detection.names
            cls_names_inv = {v:k for k,v in cls_names.items()}

            # Covert to supervision Detection format
            detection_supervision = sv.Detections.from_ultralytics(detection)

            # Convert GoalKeeper to player object
            for object_ind , class_id in enumerate(detection_supervision.class_id):
                if cls_names[class_id] == "goalkeeper":
                    detection_supervision.class_id[object_ind] = cls_names_inv["player"]

            # Track Objects
            detection_with_tracks = self.tracker.update_with_detections(detection_supervision)

            tracks["players"].append({})
            tracks["referees"].append({})
            tracks["ball"].append({})

            for frame_detection in detection_with_tracks:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]
                track_id = frame_detection[4]

                if cls_id == cls_names_inv['player']:
                    tracks["players"][frame_num][track_id] = {"bbox":bbox}

                if cls_id == cls_names_inv['referee']:
                    tracks["referees"][frame_num][track_id] = {"bbox":bbox}

            for frame_detection in detection_supervision:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]

                if cls_id == cls_names_inv['ball']:
                    tracks["ball"][frame_num][1] = {"bbox":bbox}

        return tracks

    def draw_ellipse(self,frame,bbox,color,track_id=None):
        y2 = int(bbox[3])
        x_center, _ = get_center_of_bbox(bbox)
        width = get_bbox_width(bbox)

        cv2.ellipse(
            frame,
            center=(x_center,y2),
            axes=(int(width), int(0.35*width)),
            angle=0.0,
            startAngle=-45,
            endAngle=235,
            color = color,
            thickness=2,
            lineType=cv2.LINE_4
        )

        rectangle_width = 40
        rectangle_height=20
        x1_rect = x_center - rectangle_width//2
        x2_rect = x_center + rectangle_width//2
        y1_rect = (y2- rectangle_height//2) +15
        y2_rect = (y2+ rectangle_height//2) +15

        if track_id is not None:
            cv2.rectangle(frame,
                          (int(x1_rect),int(y1_rect) ),
                          (int(x2_rect),int(y2_rect)),
                          color,
                          cv2.FILLED)

            x1_text = x1_rect+12
            if track_id > 99:
                x1_text -=10

            cv2.putText(
                frame,
                f"{track_id}",
                (int(x1_text),int(y1_rect+15)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0,0,0),
                2
            )

        return frame

    def draw_traingle(self,frame,bbox,color):
        y= int(bbox[1])
        x,_ = get_center_of_bbox(bbox)

        triangle_points = np.array([
            [x,y],
            [x-10,y-20],
            [x+10,y-20],
        ])
        cv2.drawContours(frame, [triangle_points],0,color, cv2.FILLED)
        cv2.drawContours(frame, [triangle_points],0,(0,0,0), 2)

        return frame

    def draw_annotations(self,video_frames, tracks):
        output_video_frames= []
        for frame_num, frame in enumerate(video_frames):
            frame = frame.copy()

            player_dict = tracks["players"][frame_num]
            ball_dict = tracks["ball"][frame_num]
            referee_dict = tracks["referees"][frame_num]

            # Draw Players
            for track_id, player in player_dict.items():
                color = player.get("team_color",(0,0,255))
                frame = self.draw_ellipse(frame, player["bbox"],color, track_id)

                if player.get('has_ball',False):
                    frame = self.draw_traingle(frame, player["bbox"],(0,0,255))

            # Draw Referee
            for _, referee in referee_dict.items():
                frame = self.draw_ellipse(frame, referee["bbox"],(0,255,255))

            # Draw ball
            for track_id, ball in ball_dict.items():
                frame = self.draw_traingle(frame, ball["bbox"],(0,255,0))

            output_video_frames.append(frame)

        return output_video_frames

# %% [markdown]
# # Detection and tracking on a football video

# %%
# !git clone https://github.com/Ahms9731/Project_Phase2.git
# Out:
# Cloning into 'Project_Phase2'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 11 (delta 0), reused 2 (delta 0), pack-reused 9 (from 2)
# Receiving objects: 100% (11/11), 48.10 MiB | 23.60 MiB/s, done.

# %%
from ultralytics import YOLO
yolo_path = '/content/Project_Phase2/Models/yolo_best_model.pt'

# If you wanna test it yourself, upload the video in colab local directory and replace its path here:
test_video_path = '/content/Project_Phase2/Test Videos/test_video_1.mp4'

# %%
def main():
    # Read Video
    video_frames = read_video(test_video_path)

    # Initialize Tracker
    tracker = ByteTrack_Tracker(yolo_path)

    tracks = tracker.get_object_tracks(video_frames)

    # Draw object Tracks
    output_video_frames = tracker.draw_annotations(video_frames, tracks)

    # Save video
    save_video(output_video_frames, '/content/output_video.avi')

main()
# Out:
# 0: 768x1280 2 balls, 1 goalkeeper, 21 players, 3 referees, 20.9ms
# 1: 768x1280 2 balls, 1 goalkeeper, 21 players, 3 referees, 20.9ms
# 2: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 20.9ms
# 3: 768x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 20.9ms
# 4: 768x1280 3 balls, 1 goalkeeper, 21 players, 3 referees, 20.9ms
# 5: 768x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 20.9ms
# 6: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 20.9ms
# 7: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 20.9ms
# 8: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 20.9ms
# 9: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 20.9ms
# 10: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 20.9ms
# 11: 768x1280 3 balls, 1 goalkeeper, 21 players, 3 referees, 20.9ms
# 12: 768x1280 2 balls, 1 goalkeeper, 22 players, 3 referees, 20.9ms
# 13: 768x1280 2 balls, 1 goalkeeper, 24 players, 3 referees, 20.9ms
# 14: 768x1280 1 ball, 2 goalkeepers, 23 players, 3 referees, 20.9ms
# 15: 768x1280 1 ball, 1 goalkeeper, 23 players, 3 referees, 20.9ms
# 16: 768x1280 1 ball, 22 players, 3 referees, 20.9ms
# 17: 768x1280 1 ball, 22 players, 3 referees, 20.9ms
# 18: 768x1280 2 balls, 20 players, 3 referees, 20.9ms
# 19: 768x1280 1 ball, 20 players, 3 referees, 20.9ms
# Speed: 12.9ms preprocess, 20.9ms inference, 18.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 1: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 2: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 3: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 4: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 5: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 6: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 7: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 8: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 9: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 10: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 11: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 12: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 13: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 14: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 15: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 16: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 17: 768x1280 2 balls, 20 players, 3 referees, 17.3ms
# 18: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 19: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# Speed: 12.4ms preprocess, 17.3ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 1: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 2: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 3: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 4: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 5: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 6: 768x1280 2 balls, 20 players, 3 referees, 17.2ms
# 7: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 8: 768x1280 1 ball, 20 players, 4 referees, 17.2ms
# 9: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 10: 768x1280 2 balls, 20 players, 3 referees, 17.2ms
# 11: 768x1280 20 players, 2 referees, 17.2ms
# 12: 768x1280 2 balls, 20 players, 2 referees, 17.2ms
# 13: 768x1280 1 ball, 21 players, 2 referees, 17.2ms
# 14: 768x1280 1 ball, 21 players, 2 referees, 17.2ms
# 15: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 16: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 17: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 18: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 19: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# Speed: 9.5ms preprocess, 17.2ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 1: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 2: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 3: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 4: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 5: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 6: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 7: 768x1280 1 ball, 21 players, 2 referees, 17.3ms
# 8: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 9: 768x1280 1 ball, 21 players, 2 referees, 17.3ms
# 10: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 11: 768x1280 1 ball, 21 players, 2 referees, 17.3ms
# 12: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 13: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 14: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 15: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 16: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 17: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 18: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 19: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# Speed: 9.2ms preprocess, 17.3ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 1: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 2: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 3: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 4: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 5: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 6: 768x1280 1 ball, 22 players, 2 referees, 17.2ms
# 7: 768x1280 2 balls, 21 players, 1 referee, 17.2ms
# 8: 768x1280 1 ball, 21 players, 1 referee, 17.2ms
# 9: 768x1280 1 ball, 21 players, 2 referees, 17.2ms
# 10: 768x1280 1 ball, 21 players, 2 referees, 17.2ms
# 11: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 12: 768x1280 2 balls, 20 players, 2 referees, 17.2ms
# 13: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 14: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 15: 768x1280 1 ball, 21 players, 2 referees, 17.2ms
# 16: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 17: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 18: 768x1280 1 ball, 21 players, 2 referees, 17.2ms
# 19: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# Speed: 9.7ms preprocess, 17.2ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 1: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 2: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 3: 768x1280 2 balls, 20 players, 2 referees, 17.3ms
# 4: 768x1280 1 ball, 21 players, 2 referees, 17.3ms
# 5: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 6: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 7: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 8: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 9: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 10: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 11: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 12: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 13: 768x1280 1 ball, 21 players, 2 referees, 17.3ms
# 14: 768x1280 1 ball, 21 players, 2 referees, 17.3ms
# 15: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 16: 768x1280 1 ball, 20 players, 2 referees, 17.3ms
# 17: 768x1280 2 balls, 21 players, 2 referees, 17.3ms
# 18: 768x1280 2 balls, 22 players, 2 referees, 17.3ms
# 19: 768x1280 2 balls, 22 players, 2 referees, 17.3ms
# Speed: 9.2ms preprocess, 17.3ms inference, 0.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 21 players, 2 referees, 17.2ms
# 1: 768x1280 1 ball, 22 players, 2 referees, 17.2ms
# 2: 768x1280 23 players, 2 referees, 17.2ms
# 3: 768x1280 22 players, 2 referees, 17.2ms
# 4: 768x1280 20 players, 2 referees, 17.2ms
# 5: 768x1280 1 goalkeeper, 20 players, 2 referees, 17.2ms
# 6: 768x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 17.2ms
# 7: 768x1280 1 ball, 21 players, 2 referees, 17.2ms
# 8: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 9: 768x1280 1 ball, 21 players, 2 referees, 17.2ms
# 10: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 11: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 12: 768x1280 2 balls, 20 players, 2 referees, 17.2ms
# 13: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 14: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 15: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 16: 768x1280 1 ball, 20 players, 2 referees, 17.2ms
# 17: 768x1280 1 ball, 21 players, 2 referees, 17.2ms
# 18: 768x1280 1 ball, 22 players, 2 referees, 17.2ms
# 19: 768x1280 1 ball, 22 players, 1 referee, 17.2ms
# Speed: 9.5ms preprocess, 17.2ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 22 players, 1 referee, 17.3ms
# 1: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 2: 768x1280 1 ball, 21 players, 2 referees, 17.3ms
# 3: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 4: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 5: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 6: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 7: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 8: 768x1280 2 balls, 22 players, 2 referees, 17.3ms
# 9: 768x1280 1 ball, 23 players, 2 referees, 17.3ms
# 10: 768x1280 1 ball, 23 players, 2 referees, 17.3ms
# 11: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 12: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 13: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 14: 768x1280 1 ball, 1 goalkeeper, 21 players, 2 referees, 17.3ms
# 15: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 16: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 17: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 18: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 19: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# Speed: 9.2ms preprocess, 17.3ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 1: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 2: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 3: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 4: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 5: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 6: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 7: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 8: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 9: 768x1280 1 ball, 22 players, 2 referees, 17.3ms
# 10: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 11: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 12: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 13: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 14: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 15: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 16: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 17: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 18: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 19: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# Speed: 9.7ms preprocess, 17.3ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 21 players, 4 referees, 17.3ms
# 1: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 2: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 3: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 4: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 5: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 6: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 7: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 8: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 9: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 10: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 11: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 12: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 13: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 14: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 15: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 16: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 17: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 18: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 19: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# Speed: 9.5ms preprocess, 17.3ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 23 players, 3 referees, 17.3ms
# 1: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 2: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 3: 768x1280 1 ball, 23 players, 4 referees, 17.3ms
# 4: 768x1280 1 ball, 20 players, 4 referees, 17.3ms
# 5: 768x1280 1 ball, 20 players, 4 referees, 17.3ms
# 6: 768x1280 1 ball, 21 players, 4 referees, 17.3ms
# 7: 768x1280 1 ball, 22 players, 4 referees, 17.3ms
# 8: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 9: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 10: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 11: 768x1280 1 ball, 21 players, 4 referees, 17.3ms
# 12: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 13: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 14: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 15: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 16: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 17: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 18: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 19: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# Speed: 9.6ms preprocess, 17.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 1: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 2: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 3: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 4: 768x1280 1 ball, 20 players, 4 referees, 17.2ms
# 5: 768x1280 1 ball, 20 players, 4 referees, 17.2ms
# 6: 768x1280 20 players, 3 referees, 17.2ms
# 7: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 8: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 9: 768x1280 1 ball, 22 players, 2 referees, 17.2ms
# 10: 768x1280 1 ball, 23 players, 3 referees, 17.2ms
# 11: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 12: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 13: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 14: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 15: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 16: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 17: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 18: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 19: 768x1280 20 players, 3 referees, 17.2ms
# Speed: 9.2ms preprocess, 17.2ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 20 players, 3 referees, 17.2ms
# 1: 768x1280 20 players, 3 referees, 17.2ms
# 2: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 3: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 4: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 5: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 6: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 7: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 8: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 9: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 10: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 11: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 12: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 13: 768x1280 1 ball, 20 players, 4 referees, 17.2ms
# 14: 768x1280 1 ball, 20 players, 4 referees, 17.2ms
# 15: 768x1280 1 ball, 22 players, 4 referees, 17.2ms
# 16: 768x1280 1 ball, 21 players, 4 referees, 17.2ms
# 17: 768x1280 1 ball, 20 players, 4 referees, 17.2ms
# 18: 768x1280 1 ball, 22 players, 4 referees, 17.2ms
# 19: 768x1280 1 ball, 22 players, 3 referees, 17.2ms
# Speed: 9.4ms preprocess, 17.2ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 22 players, 3 referees, 17.2ms
# 1: 768x1280 1 ball, 22 players, 3 referees, 17.2ms
# 2: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 3: 768x1280 1 ball, 22 players, 3 referees, 17.2ms
# 4: 768x1280 1 ball, 23 players, 3 referees, 17.2ms
# 5: 768x1280 21 players, 3 referees, 17.2ms
# 6: 768x1280 21 players, 3 referees, 17.2ms
# 7: 768x1280 20 players, 3 referees, 17.2ms
# 8: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 9: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 10: 768x1280 2 balls, 20 players, 3 referees, 17.2ms
# 11: 768x1280 2 balls, 21 players, 3 referees, 17.2ms
# 12: 768x1280 2 balls, 21 players, 3 referees, 17.2ms
# 13: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 14: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 15: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 16: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 17: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 18: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 19: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# Speed: 9.3ms preprocess, 17.2ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 1: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 2: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 3: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 4: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 5: 768x1280 1 ball, 19 players, 3 referees, 17.3ms
# 6: 768x1280 1 ball, 18 players, 3 referees, 17.3ms
# 7: 768x1280 1 ball, 18 players, 3 referees, 17.3ms
# 8: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 9: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 10: 768x1280 1 ball, 24 players, 3 referees, 17.3ms
# 11: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 12: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 13: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 14: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 15: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 16: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 17: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 18: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 19: 768x1280 20 players, 3 referees, 17.3ms
# Speed: 9.3ms preprocess, 17.3ms inference, 1.3ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 20 players, 3 referees, 17.4ms
# 1: 768x1280 21 players, 3 referees, 17.4ms
# 2: 768x1280 21 players, 3 referees, 17.4ms
# 3: 768x1280 21 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 22 players, 3 referees, 17.4ms
# 5: 768x1280 21 players, 3 referees, 17.4ms
# 6: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 7: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 9: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 10: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 11: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 12: 768x1280 2 balls, 21 players, 3 referees, 17.4ms
# 13: 768x1280 2 balls, 21 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 15: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 16: 768x1280 1 ball, 22 players, 3 referees, 17.4ms
# 17: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 18: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 19: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# Speed: 14.2ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 1: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 2: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 3: 768x1280 1 ball, 23 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 22 players, 3 referees, 17.4ms
# 5: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 6: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 7: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 22 players, 3 referees, 17.4ms
# 9: 768x1280 1 ball, 22 players, 3 referees, 17.4ms
# 10: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 11: 768x1280 22 players, 3 referees, 17.4ms
# 12: 768x1280 21 players, 3 referees, 17.4ms
# 13: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 22 players, 3 referees, 17.4ms
# 15: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 16: 768x1280 1 ball, 22 players, 3 referees, 17.4ms
# 17: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 18: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 19: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# Speed: 14.8ms preprocess, 17.4ms inference, 1.3ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 1: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 2: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 3: 768x1280 22 players, 3 referees, 17.2ms
# 4: 768x1280 22 players, 3 referees, 17.2ms
# 5: 768x1280 21 players, 3 referees, 17.2ms
# 6: 768x1280 1 ball, 22 players, 3 referees, 17.2ms
# 7: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 8: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 9: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 10: 768x1280 1 ball, 1 goalkeeper, 24 players, 3 referees, 17.2ms
# 11: 768x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 17.2ms
# 12: 768x1280 2 balls, 1 goalkeeper, 21 players, 3 referees, 17.2ms
# 13: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.2ms
# 14: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.2ms
# 15: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.2ms
# 16: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.2ms
# 17: 768x1280 1 ball, 20 players, 3 referees, 17.2ms
# 18: 768x1280 1 ball, 21 players, 3 referees, 17.2ms
# 19: 768x1280 20 players, 3 referees, 17.2ms
# Speed: 14.8ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 1: 768x1280 20 players, 3 referees, 17.3ms
# 2: 768x1280 20 players, 3 referees, 17.3ms
# 3: 768x1280 22 players, 3 referees, 17.3ms
# 4: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 5: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 6: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 7: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 8: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 9: 768x1280 2 balls, 21 players, 3 referees, 17.3ms
# 10: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 11: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 12: 768x1280 21 players, 3 referees, 17.3ms
# 13: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 14: 768x1280 19 players, 3 referees, 17.3ms
# 15: 768x1280 1 ball, 19 players, 3 referees, 17.3ms
# 16: 768x1280 2 balls, 20 players, 3 referees, 17.3ms
# 17: 768x1280 1 ball, 19 players, 3 referees, 17.3ms
# 18: 768x1280 1 ball, 19 players, 3 referees, 17.3ms
# 19: 768x1280 1 ball, 19 players, 3 referees, 17.3ms
# Speed: 14.8ms preprocess, 17.3ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 20 players, 3 referees, 17.4ms
# 1: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 2: 768x1280 19 players, 3 referees, 17.4ms
# 3: 768x1280 21 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 5: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 6: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 7: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 9: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 10: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 11: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 12: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 13: 768x1280 1 ball, 19 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 19 players, 3 referees, 17.4ms
# 15: 768x1280 19 players, 3 referees, 17.4ms
# 16: 768x1280 19 players, 2 referees, 17.4ms
# 17: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 18: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 19: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# Speed: 9.4ms preprocess, 17.4ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 22 players, 3 referees, 17.3ms
# 1: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 2: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 3: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 4: 768x1280 1 ball, 21 players, 3 referees, 17.3ms
# 5: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 6: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 7: 768x1280 1 ball, 19 players, 3 referees, 17.3ms
# 8: 768x1280 1 ball, 19 players, 3 referees, 17.3ms
# 9: 768x1280 19 players, 3 referees, 17.3ms
# 10: 768x1280 1 ball, 19 players, 3 referees, 17.3ms
# 11: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 12: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 13: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 14: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 15: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 16: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 17: 768x1280 1 ball, 20 players, 3 referees, 17.3ms
# 18: 768x1280 20 players, 3 referees, 17.3ms
# 19: 768x1280 20 players, 3 referees, 17.3ms
# Speed: 9.7ms preprocess, 17.3ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 20 players, 3 referees, 17.4ms
# 1: 768x1280 20 players, 3 referees, 17.4ms
# 2: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 3: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 5: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 6: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 7: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 9: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 10: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 11: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 12: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 13: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 15: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 16: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 17: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 18: 768x1280 1 ball, 20 players, 4 referees, 17.4ms
# 19: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# Speed: 10.2ms preprocess, 17.4ms inference, 0.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 1: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 2: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 3: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 5: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 6: 768x1280 20 players, 3 referees, 17.4ms
# 7: 768x1280 20 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 9: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 10: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 11: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 12: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 13: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 15: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 16: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 17: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 18: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 19: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# Speed: 9.2ms preprocess, 17.4ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 1: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 2: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 3: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 5: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 6: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 7: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 9: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 10: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 11: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 12: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 13: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 15: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 16: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 17: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 18: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 19: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# Speed: 9.2ms preprocess, 17.4ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 1: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 2: 768x1280 1 ball, 21 players, 3 referees, 17.4ms
# 3: 768x1280 20 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 5: 768x1280 20 players, 3 referees, 17.4ms
# 6: 768x1280 21 players, 3 referees, 17.4ms
# 7: 768x1280 20 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 9: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 10: 768x1280 1 ball, 20 players, 3 referees, 17.4ms
# 11: 768x1280 2 balls, 20 players, 3 referees, 17.4ms
# 12: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 13: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 15: 768x1280 2 balls, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 16: 768x1280 2 balls, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 17: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 18: 768x1280 2 balls, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 19: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# Speed: 13.5ms preprocess, 17.4ms inference, 2.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 1: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 2: 768x1280 2 balls, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 3: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 4: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 5: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.8ms
# 6: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 7: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 8: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 9: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 10: 768x1280 2 balls, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 11: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 12: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 13: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 14: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 15: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 16: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 17: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 18: 768x1280 3 balls, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# 19: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.8ms
# Speed: 21.8ms preprocess, 17.8ms inference, 2.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 1: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 2: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 3: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 4: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 5: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 6: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 7: 768x1280 1 goalkeeper, 21 players, 3 referees, 17.5ms
# 8: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.5ms
# 9: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.5ms
# 10: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.5ms
# 11: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.5ms
# 12: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 13: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.5ms
# 14: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 15: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 16: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 17: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 18: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.5ms
# 19: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.5ms
# Speed: 21.4ms preprocess, 17.5ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 1: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 2: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 3: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 5: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 6: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 7: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 9: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 10: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 11: 768x1280 1 ball, 3 goalkeepers, 20 players, 3 referees, 17.4ms
# 12: 768x1280 1 ball, 3 goalkeepers, 20 players, 3 referees, 17.4ms
# 13: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 15: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 16: 768x1280 1 ball, 3 goalkeepers, 19 players, 3 referees, 17.4ms
# 17: 768x1280 1 ball, 3 goalkeepers, 20 players, 3 referees, 17.4ms
# 18: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 19: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# Speed: 24.7ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.5ms
# 1: 768x1280 1 ball, 2 goalkeepers, 21 players, 3 referees, 17.5ms
# 2: 768x1280 2 balls, 2 goalkeepers, 21 players, 3 referees, 17.5ms
# 3: 768x1280 2 balls, 2 goalkeepers, 21 players, 3 referees, 17.5ms
# 4: 768x1280 3 goalkeepers, 21 players, 3 referees, 17.5ms
# 5: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.5ms
# 6: 768x1280 2 goalkeepers, 21 players, 3 referees, 17.5ms
# 7: 768x1280 1 ball, 2 goalkeepers, 21 players, 3 referees, 17.5ms
# 8: 768x1280 2 goalkeepers, 21 players, 3 referees, 17.5ms
# 9: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.5ms
# 10: 768x1280 1 goalkeeper, 21 players, 3 referees, 17.5ms
# 11: 768x1280 1 goalkeeper, 21 players, 3 referees, 17.5ms
# 12: 768x1280 2 goalkeepers, 21 players, 3 referees, 17.5ms
# 13: 768x1280 2 goalkeepers, 21 players, 3 referees, 17.5ms
# 14: 768x1280 2 goalkeepers, 21 players, 3 referees, 17.5ms
# 15: 768x1280 2 goalkeepers, 21 players, 3 referees, 17.5ms
# 16: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.5ms
# 17: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.5ms
# 18: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.5ms
# 19: 768x1280 1 ball, 2 goalkeepers, 21 players, 3 referees, 17.5ms
# Speed: 21.4ms preprocess, 17.5ms inference, 0.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.3ms
# 1: 768x1280 3 goalkeepers, 20 players, 3 referees, 17.3ms
# 2: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.3ms
# 3: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.3ms
# 4: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.3ms
# 5: 768x1280 1 ball, 2 goalkeepers, 21 players, 3 referees, 17.3ms
# 6: 768x1280 2 goalkeepers, 21 players, 3 referees, 17.3ms
# 7: 768x1280 1 ball, 3 goalkeepers, 21 players, 3 referees, 17.3ms
# 8: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.3ms
# 9: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.3ms
# 10: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.3ms
# 11: 768x1280 2 goalkeepers, 19 players, 3 referees, 17.3ms
# 12: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.3ms
# 13: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.3ms
# 14: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.3ms
# 15: 768x1280 1 ball, 2 goalkeepers, 21 players, 3 referees, 17.3ms
# 16: 768x1280 1 ball, 2 goalkeepers, 21 players, 3 referees, 17.3ms
# 17: 768x1280 1 ball, 2 goalkeepers, 21 players, 3 referees, 17.3ms
# 18: 768x1280 2 goalkeepers, 19 players, 3 referees, 17.3ms
# 19: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.3ms
# Speed: 9.4ms preprocess, 17.3ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 1: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 2: 768x1280 1 ball, 3 goalkeepers, 19 players, 3 referees, 17.4ms
# 3: 768x1280 2 balls, 3 goalkeepers, 19 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 3 goalkeepers, 19 players, 3 referees, 17.4ms
# 5: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 6: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 7: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 9: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 10: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 11: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 12: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 13: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 15: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 16: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.4ms
# 17: 768x1280 3 goalkeepers, 19 players, 3 referees, 17.4ms
# 18: 768x1280 3 goalkeepers, 19 players, 3 referees, 17.4ms
# 19: 768x1280 1 goalkeeper, 19 players, 3 referees, 17.4ms
# Speed: 9.2ms preprocess, 17.4ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 goalkeeper, 19 players, 3 referees, 17.4ms
# 1: 768x1280 1 goalkeeper, 19 players, 3 referees, 17.4ms
# 2: 768x1280 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 3: 768x1280 1 goalkeeper, 19 players, 3 referees, 17.4ms
# 4: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 5: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 6: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 7: 768x1280 1 goalkeeper, 21 players, 3 referees, 17.4ms
# 8: 768x1280 1 goalkeeper, 21 players, 3 referees, 17.4ms
# 9: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 10: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 11: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 12: 768x1280 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 13: 768x1280 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 14: 768x1280 2 goalkeepers, 20 players, 4 referees, 17.4ms
# 15: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 16: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 17: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 18: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 19: 768x1280 2 balls, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# Speed: 9.2ms preprocess, 17.4ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 1: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 2: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 3: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 5: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.4ms
# 6: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 7: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 9: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 10: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 11: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 12: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 13: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 15: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 16: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 17: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 18: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 19: 768x1280 1 ball, 2 goalkeepers, 19 players, 3 referees, 17.4ms
# Speed: 10.0ms preprocess, 17.4ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 1: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 2: 768x1280 2 goalkeepers, 20 players, 4 referees, 17.4ms
# 3: 768x1280 1 goalkeeper, 20 players, 4 referees, 17.4ms
# 4: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 5: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 6: 768x1280 1 goalkeeper, 21 players, 3 referees, 17.4ms
# 7: 768x1280 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 8: 768x1280 2 goalkeepers, 19 players, 3 referees, 17.4ms
# 9: 768x1280 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 10: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 11: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 12: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 13: 768x1280 1 goalkeeper, 19 players, 3 referees, 17.4ms
# 14: 768x1280 1 goalkeeper, 21 players, 3 referees, 17.4ms
# 15: 768x1280 1 ball, 2 goalkeepers, 21 players, 2 referees, 17.4ms
# 16: 768x1280 1 ball, 2 goalkeepers, 20 players, 3 referees, 17.4ms
# 17: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.4ms
# 18: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.4ms
# 19: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.4ms
# Speed: 9.4ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 1: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 2: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 3: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 5: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 6: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 7: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 8: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 9: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 10: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 11: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 12: 768x1280 2 balls, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 13: 768x1280 2 balls, 1 goalkeeper, 21 players, 3 referees, 17.4ms
# 14: 768x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 17.4ms
# 15: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.4ms
# 16: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 17: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 18: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 19: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# Speed: 14.3ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 2 balls, 1 goalkeeper, 19 players, 3 referees, 17.6ms
# 1: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.6ms
# 2: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.6ms
# 3: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.6ms
# 4: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.6ms
# 5: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.6ms
# 6: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.6ms
# 7: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.6ms
# 8: 768x1280 1 ball, 1 goalkeeper, 19 players, 3 referees, 17.6ms
# 9: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.6ms
# 10: 768x1280 1 goalkeeper, 22 players, 3 referees, 17.6ms
# 11: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.6ms
# 12: 768x1280 1 goalkeeper, 21 players, 3 referees, 17.6ms
# 13: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.6ms
# 14: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.6ms
# 15: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.6ms
# 16: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.6ms
# 17: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.6ms
# 18: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.6ms
# 19: 768x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 17.6ms
# Speed: 16.0ms preprocess, 17.6ms inference, 1.4ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 1: 768x1280 2 balls, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 2: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 3: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.4ms
# 4: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 5: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 17.4ms
# 6: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 7: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 8: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 9: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 10: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 11: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 12: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 13: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 14: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 15: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 16: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 17: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 18: 768x1280 1 goalkeeper, 20 players, 3 referees, 17.4ms
# 19: 768x1280 1 goalkeeper, 21 players, 3 referees, 17.4ms
# Speed: 14.7ms preprocess, 17.4ms inference, 1.3ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 goalkeeper, 21 players, 3 referees, 18.5ms
# 1: 768x1280 1 goalkeeper, 21 players, 3 referees, 18.5ms
# 2: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 18.5ms
# 3: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 18.5ms
# 4: 768x1280 1 ball, 1 goalkeeper, 21 players, 3 referees, 18.5ms
# 5: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 18.5ms
# 6: 768x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 18.5ms
# 7: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 18.5ms
# 8: 768x1280 1 goalkeeper, 21 players, 3 referees, 18.5ms
# 9: 768x1280 1 ball, 1 goalkeeper, 20 players, 3 referees, 18.5ms
# Speed: 15.2ms preprocess, 18.5ms inference, 1.3ms postprocess per image at shape (1, 3, 768, 1280)
